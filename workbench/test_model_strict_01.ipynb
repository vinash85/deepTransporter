# %%
import os
import torch
from torch.cuda.amp import autocast, GradScaler
from torch_geometric.data import Data
import pandas as pd
import numpy as np
import torch.nn as nn
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score
import copy
import random
import multiprocessing as mp
from torch_geometric.data import HeteroData
import torch
from torch_geometric.nn import GCNConv
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
# Enable CUDA debugging, use to block cuda calls until completion
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
# Load node datasets
s_df = pd.read_csv('/data/servilla/DT_HGNN/Model/Nodes/s_emb_full_183.csv', index_col=0) # Substrates
p_df = pd.read_csv('/data/servilla/DT_HGNN/Model/Nodes/p_emb_full_237197.csv', index_col=0) # Proteins

# %%
# Load edge datasets (combined with negative samples)
ppi_df = pd.read_csv('/data/servilla/DT_HGNN/Model/Edges/combined_ppi_edges_full.csv') # Protein-Protein Interactions
ssi_df = pd.read_csv('/data/servilla/DT_HGNN/Model/Edges/combined_ssi_edges_full.csv') # Substrate-Substrate Interactions
tp_s_df = pd.read_csv('/data/servilla/DT_HGNN/Model/Edges/combined_tp_s_edges_full.csv',) # Transporter Protein-Substrate Interactions

# %%
# Inspect and clean the data, node dataframes should be numeric
def inspect_and_clean(df):
    non_numeric_columns = df.select_dtypes(exclude=[np.number]).columns
    print(f"Non-numeric columns: {non_numeric_columns}")
    if len(non_numeric_columns) > 0:
        df[non_numeric_columns] = df[non_numeric_columns].apply(pd.to_numeric, errors='coerce')
    df = df.fillna(0)
    return df

# %%
def get_mapping(p_dataframe, s_dataframe):
    protein_mapping = {protein_id: i for i, protein_id in enumerate(p_dataframe.index)}
    substrate_mapping = {substrate_id: i for i, substrate_id in enumerate(s_dataframe.index)}
    return protein_mapping, substrate_mapping

# %%
def map_edges_debug(edge_df, source_mapping, target_mapping, edge_type):
    edge_df = edge_df.copy()

    # Apply mapping
    edge_df['source'] = edge_df['source'].map(source_mapping)
    edge_df['target'] = edge_df['target'].map(target_mapping)

    # Drop rows with NaNs in mapped columns
    edge_df.dropna(subset=['source', 'target'], inplace=True)
      
    return edge_df

# %%
# Apply transformations in batches, this can be useful when dealing with large 
# datasets that may not fit into memory or GPU all at once. 
def transform_in_batches(features, transform_layer, batch_size=10000):
    num_samples = features.shape[0]
    print(f"Number of samples: {num_samples}")
    transformed_features = []
    for i in range(0, num_samples, batch_size):
        batch = features[i:i + batch_size]
        batch_tensor = torch.tensor(batch, dtype=torch.float).to(device)
        transformed_batch = transform_layer(batch_tensor)
        transformed_features.append(transformed_batch.detach().cpu().numpy())  # Use detach() before numpy()
    return np.vstack(transformed_features) # Stack arrays in sequence vertically (row wise)

# %%
# Function to remove rows where source or target is in test_proteins or test_substrates
def filter_out_test_edges(df, protein_set, substrate_set):
    # For cases where the DataFrame has both 'source' and 'target' columns
    if 'source' in df.columns and 'target' in df.columns:
        filtered_df = df[~(df['source'].isin(protein_set) | df['target'].isin(substrate_set))]
    # For cases where the DataFrame only has an index, such as node DataFrames
    else:
        filtered_df = df[~df.index.isin(protein_set | substrate_set)]
    return filtered_df

# %%
def split_train_val_data(df, train_size=0.9, val_size=0.1):
    # Split into train and validation (90% train, 10% validation)
    train_df, val_df = train_test_split(df, train_size=train_size, random_state=42)
    
    return train_df, val_df

# %%
# Create edge index tensors for training, validation, and test
def get_tensor(df):
    return torch.tensor(df[['source', 'target']].values.T, dtype=torch.long)

# %%
# Labels remain the same
def get_labels(df):
    return torch.tensor(df['label'].values, dtype=torch.float)

# %%
s_df = inspect_and_clean(s_df)
p_df = inspect_and_clean(p_df)
# Out:
# Non-numeric columns: Index([], dtype='object')
# Non-numeric columns: Index([], dtype='object')

# %%
protein_mapping, substrate_mapping = get_mapping(p_df, s_df)

# %%
# Apply the debugging function to map edges
mapped_ppi_edges_df = map_edges_debug(ppi_df, protein_mapping, protein_mapping, 'PPI')
mapped_ssi_edges_df = map_edges_debug(ssi_df, substrate_mapping, substrate_mapping, 'SSI')
mapped_tp_s_df = map_edges_debug(tp_s_df, protein_mapping, substrate_mapping, 'TP-S')

# %%
from sklearn.model_selection import train_test_split

# Randomly select 50 samples for the test set from the mapped tp_s_df
test_tp_s_df = tp_s_df.sample(n=50, random_state=42)

# Remove the selected test samples from the original mapped_tp_s_df to form the training set
train_tp_s_df = tp_s_df.drop(test_tp_s_df.index)

# Check the sizes of the resulting DataFrames
print(f"Training set size: {train_tp_s_df.shape[0]}")
print(f"Test set size: {test_tp_s_df.shape[0]}")
# Out:
# Training set size: 26630
# Test set size: 50

# %%
# Convert the mapped indices back to the original Uniprot IDs and ChEBI IDs
test_proteins = test_tp_s_df['source'].unique()
test_substrates = test_tp_s_df['target'].unique()

# Step 2: Split p_df into train and test based on test_proteins
p_test_df = p_df[p_df.index.isin(test_proteins)]  # Test set for proteins
p_train_df = p_df[~p_df.index.isin(test_proteins)]  # Train set for proteins

# Step 3: Split s_df into train and test based on test_substrates
s_test_df = s_df[s_df.index.isin(test_substrates)]  # Test set for substrates
s_train_df = s_df[~s_df.index.isin(test_substrates)]  # Train set for substrates

# Check the sizes of the resulting DataFrames
print(f"Protein training set size: {p_train_df.shape[0]}")
print(f"Protein test set size: {p_test_df.shape[0]}")
print(f"Substrate training set size: {s_train_df.shape[0]}")
print(f"Substrate test set size: {s_test_df.shape[0]}")
# Out:
# Protein training set size: 237147
# Protein test set size: 50
# Substrate training set size: 147
# Substrate test set size: 36

# %%
# train_tp_s_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Edges/train_tp_s_edges.csv', index=False)
# test_tp_s_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Edges/test_tp_s_edges.csv', index=False)
# ppi_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Edges/ppi_edges.csv', index=False)
# ssi_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Edges/ssi_edges.csv', index=False)
# p_train_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Nodes/p_train.csv')
# p_test_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Nodes/p_test.csv')
# s_train_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Nodes/s_train.csv')
# s_test_df.to_csv('/data/servilla/DT_HGNN/Model/Strict_testing_datasets/STD_Nodes/s_test.csv')

# %%
# Convert features to numpy arrays
s_features = s_train_df.values
p_features = p_train_df.values

# %%
# Check shapes to ensure correct dimensions
print(f"s_features shape: {s_features.shape}")  # Expected (183, 1536)
print(f"p_features shape: {p_features.shape}")  # Expected (237197, 2048)
# Out:
# s_features shape: (147, 1536)
# p_features shape: (237147, 2048)

# %%
# Normalize node features (normalizes columns to have mean 0 and variance 1)
s_features = (s_features - np.mean(s_features, axis=0)) / np.std(s_features, axis=0)
p_features = (p_features - np.mean(p_features, axis=0)) / np.std(p_features, axis=0)

# %%
# Define the transformation layers, changes the number of features 1536 -> 2048
# for substrates and 2048 -> 2048 for proteins. The transform_p layer is useful 
# for transforming the feature representation within the same dimensional space,
#  y = Wx + b.

device = torch.device('cpu')  # Temporarily switch to CPU


transform_s = Linear(1536, 2048).to(device) # Change depending on the number of features
transform_p = Linear(2048, 2048).to(device)

# %%
s_features_transformed = transform_in_batches(s_features, transform_s)
p_features_transformed = transform_in_batches(p_features, transform_p)
# Out:
# Number of samples: 147
# Number of samples: 237147

# %%
# Convert back to tensors
s_features_tensor = torch.tensor(s_features_transformed, dtype=torch.float).to(device)
p_features_tensor = torch.tensor(p_features_transformed, dtype=torch.float).to(device)

# %%
# Combine features, vertically stacks features (dim=0) to create a single tensor
all_features = torch.cat([p_features_tensor, s_features_tensor], dim=0)

# %%
protein_ids = set(p_df.index)
substrate_ids = set(s_df.index)

# %%
protein_mapping, substrate_mapping = get_mapping(p_train_df, s_train_df)

# %%
# Get the unique source and target values from test_tp_s_df
test_proteins = set(test_tp_s_df['source'].unique())
test_substrates = set(test_tp_s_df['target'].unique())

# Apply the function to remove rows from all DataFrames
train_tp_s_df = filter_out_test_edges(train_tp_s_df, test_proteins, test_substrates)
ppi_filtered_df = filter_out_test_edges(ppi_df, test_proteins, test_proteins)  # PPI only involves proteins
ssi_filtered_df = filter_out_test_edges(ssi_df, test_substrates, test_substrates)  # SSI only involves substrates

# %%
# Apply the debugging function to map edges
mapped_ppi_edges_df = map_edges_debug(ppi_filtered_df, protein_mapping, protein_mapping, 'PPI')
mapped_ssi_edges_df = map_edges_debug(ssi_filtered_df, substrate_mapping, substrate_mapping, 'SSI')
mapped_tp_s_df = map_edges_debug(train_tp_s_df, protein_mapping, substrate_mapping, 'TP-S')

# %%
# Split data for each edge type (without test, as test is predefined)
ppi_train_df, ppi_val_df = split_train_val_data(mapped_ppi_edges_df)
ssi_train_df, ssi_val_df = split_train_val_data(mapped_ssi_edges_df)
tp_s_train_df, tp_s_val_df = split_train_val_data(mapped_tp_s_df)

# %%
# Create edge index tensors for training, validation, and test
train_edges_tp_s = torch.tensor(tp_s_train_df[['source', 'target']].values.T, dtype=torch.long)
val_edges_tp_s = torch.tensor(tp_s_val_df[['source', 'target']].values.T, dtype=torch.long)

train_edges_ppi = torch.tensor(ppi_train_df[['source', 'target']].values.T, dtype=torch.long)
val_edges_ppi = torch.tensor(ppi_val_df[['source', 'target']].values.T, dtype=torch.long)

train_edges_ssi = torch.tensor(ssi_train_df[['source', 'target']].values.T, dtype=torch.long)
val_edges_ssi = torch.tensor(ssi_val_df[['source', 'target']].values.T, dtype=torch.long)

# Labels remain the same
train_labels_tp_s = torch.tensor(tp_s_train_df['label'].values, dtype=torch.float)
val_labels_tp_s = torch.tensor(tp_s_val_df['label'].values, dtype=torch.float)

train_labels_ppi = torch.tensor(ppi_train_df['label'].values, dtype=torch.float)
val_labels_ppi = torch.tensor(ppi_val_df['label'].values, dtype=torch.float)

train_labels_ssi = torch.tensor(ssi_train_df['label'].values, dtype=torch.float)
val_labels_ssi = torch.tensor(ssi_val_df['label'].values, dtype=torch.float)

# %%
print(f"p_df: {p_df.shape}")
print(f"p_train_df: {p_train_df.shape}")
print(f"p_test_df: {p_test_df.shape}")
print(f"s_df: {s_df.shape}")
print(f"s_train_df: {s_train_df.shape}")
print(f"s_test_df: {s_test_df.shape}")
print(f"tp_s_df: {tp_s_df.shape}")
print(f"test_tp_s_df: {test_tp_s_df.shape}")
print(f"train_tp_s_df: {train_tp_s_df.shape}")
print(f"ppi_df: {ppi_df.shape}")
print(f"ppi_filtered_df: {ppi_filtered_df.shape}")
print(f"ssi_df: {ssi_df.shape}")
print(f"ssi_filtered_df: {ssi_filtered_df.shape}")
# Out:
# p_df: (237197, 2048)
# p_train_df: (237147, 2048)
# p_test_df: (50, 2048)
# s_df: (183, 1536)
# s_train_df: (147, 1536)
# s_test_df: (36, 1536)
# tp_s_df: (26680, 3)
# test_tp_s_df: (50, 3)
# train_tp_s_df: (12288, 3)
# ppi_df: (13327046, 3)
# ppi_filtered_df: (13322673, 3)
# ssi_df: (4354, 3)
# ssi_filtered_df: (2434, 3)

# %%
print(f"Training TP-S edges: {train_edges_tp_s.shape}")
print(f"Validation TP-S edges: {val_edges_tp_s.shape}")
print(f"Training PPI edges: {train_edges_ppi.shape}")
print(f"Validation PPI edges: {val_edges_ppi.shape}")
print(f"Training SSI edges: {train_edges_ssi.shape}")
print(f"Validation SSI edges: {val_edges_ssi.shape}")
# Out:
# Training TP-S edges: torch.Size([2, 11059])
# Validation TP-S edges: torch.Size([2, 1229])
# Training PPI edges: torch.Size([2, 11990405])
# Validation PPI edges: torch.Size([2, 1332268])
# Training SSI edges: torch.Size([2, 2190])
# Validation SSI edges: torch.Size([2, 244])

# %%
positive_tp_s_train_df = tp_s_train_df[tp_s_train_df['label'] == 1]

train_edges_tp_s_positive = torch.tensor(positive_tp_s_train_df[['source', 'target']].values.T, dtype=torch.long)

# positive_ppi_train_df = ppi_train_df[ppi_train_df['label'] == 1]

# train_edges_ppi_positive = torch.tensor(positive_tp_s_train_df[['source', 'target']].values.T, dtype=torch.long)

# positive_ssi_train_df = ssi_train_df[ssi_train_df['label'] == 1]

# train_edges_ssi_positive = torch.tensor(positive_ssi_train_df[['source', 'target']].values.T, dtype=torch.long)

# %%
data = HeteroData()

# Assign node features
data['protein'].x = p_features_tensor
data['substrate'].x = s_features_tensor

# Assign training edges
data['protein', 'interacts_with', 'substrate'].edge_index = train_edges_tp_s
data['protein', 'interacts_with', 'protein'].edge_index = train_edges_ppi
data['substrate', 'interacts_with', 'substrate'].edge_index = train_edges_ssi

# %%
# Initialize the model
class GCNLinkPredictor(nn.Module):
    def __init__(self, protein_dim, substrate_dim, hidden_channels):
        super(GCNLinkPredictor, self).__init__()
        self.protein_conv1 = GCNConv(protein_dim, hidden_channels)
        self.substrate_conv1 = GCNConv(substrate_dim, hidden_channels)
        self.protein_conv2 = GCNConv(hidden_channels, hidden_channels)
        self.substrate_conv2 = GCNConv(hidden_channels, hidden_channels)
        self.link_predictor = nn.Sequential(
            nn.Linear(hidden_channels * 2, hidden_channels),
            nn.ReLU(),
            nn.Linear(hidden_channels, 1)
        )

    def encode(self, x_dict, edge_index_dict):
        z_protein = self.protein_conv1(x_dict['protein'], edge_index_dict[('protein', 'interacts_with', 'protein')])
        z_substrate = self.substrate_conv1(x_dict['substrate'], edge_index_dict[('substrate', 'interacts_with', 'substrate')])
        return z_protein, z_substrate

    def forward(self, x_dict, edge_index_dict, edges):
        z_protein, z_substrate = self.encode(x_dict, edge_index_dict)
        z_combined = torch.cat([z_protein[edges[0]], z_substrate[edges[1]]], dim=-1)
        return self.link_predictor(z_combined).squeeze()


# Initialize the model
model = GCNLinkPredictor(protein_dim=2048, substrate_dim=2048, hidden_channels=64).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion = torch.nn.BCEWithLogitsLoss()

# Early stopping parameters
patience = 10  # Number of epochs to wait before stopping if no improvement
best_val_loss = float('inf')
epochs_without_improvement = 0

# Learning Rate Scheduler
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4)


# Assuming `data` contains x_dict and edge_index_dict
x_dict = data.x_dict
edge_index_dict = data.edge_index_dict



# Update the train, validate, and test functions as needed
def train(x_dict, edge_index_dict, train_edges_tp_s, train_labels_tp_s): 
    model.train()
    optimizer.zero_grad()
    out = model(x_dict, edge_index_dict, train_edges_tp_s)
    loss = criterion(out, train_labels_tp_s)
    loss.backward()
    optimizer.step()
    return loss.item(), out.detach()

def validate():
    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict, val_edges_tp_s)
        loss = criterion(out, val_labels_tp_s)
    return loss.item(), out

def test(x_dict, edge_index_dict, test_edges_tp_s, test_labels_tp_s):
    model.eval()
    with torch.no_grad():
        out = model(x_dict, edge_index_dict, test_edges_tp_s)
        loss = criterion(out, test_labels_tp_s)
        accuracy, precision, recall, f1, auc = calculate_metrics(test_labels_tp_s, out)
    return loss.item(), accuracy, precision, recall, f1, auc

# Calculate additional metrics
def calculate_metrics(labels, preds):
    preds = torch.sigmoid(preds).cpu().numpy()
    preds_binary = (preds > 0.5).astype(int)
    labels = labels.cpu().numpy()

    accuracy = accuracy_score(labels, preds_binary)
    precision = precision_score(labels, preds_binary)
    recall = recall_score(labels, preds_binary)
    f1 = f1_score(labels, preds_binary)
    auc = roc_auc_score(labels, preds)

    return accuracy, precision, recall, f1, auc

# Modify the training loop to include metric calculation and visualization
train_losses = []
val_losses = []
val_accuracies = []

# Training loop
epochs = 500
for epoch in range(epochs):
    # Training step
    train_loss, train_preds = train(x_dict, edge_index_dict, train_edges_tp_s, train_labels_tp_s)
    # Validation step
    val_loss, val_preds = validate()

    # Store losses
    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # Calculate validation metrics
    accuracy, precision, recall, f1, auc = calculate_metrics(val_labels_tp_s, val_preds)
    val_accuracies.append(accuracy)

    # Print metrics
    print(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, "
          f"Val Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, "
          f"F1: {f1:.4f}, AUC: {auc:.4f}, LR: {scheduler.get_last_lr()[0]}")

    # Step the LR scheduler
    scheduler.step(val_loss)

    # Check for early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_without_improvement = 0
        torch.save(model.state_dict(), '/data/servilla/DT_HGNN/data/Models_saves/best_model.pth')  # Save the best model
    else:
        epochs_without_improvement += 1
    
    if epochs_without_improvement >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break
# Out:
# Epoch 1, Train Loss: 0.7608, Validation Loss: 0.7518, Val Accuracy: 0.2205, Precision: 0.1331, Recall: 0.8780, F1: 0.2311, AUC: 0.5484, LR: 0.0001
# Epoch 2, Train Loss: 0.7513, Validation Loss: 0.7427, Val Accuracy: 0.2539, Precision: 0.1404, Recall: 0.8963, F1: 0.2428, AUC: 0.6018, LR: 0.0001
# Epoch 3, Train Loss: 0.7420, Validation Loss: 0.7338, Val Accuracy: 0.2994, Precision: 0.1505, Recall: 0.9146, F1: 0.2584, AUC: 0.6519, LR: 0.0001
# Epoch 4, Train Loss: 0.7328, Validation Loss: 0.7251, Val Accuracy: 0.3303, Precision: 0.1564, Recall: 0.9146, F1: 0.2671, AUC: 0.6951, LR: 0.0001
# Epoch 5, Train Loss: 0.7238, Validation Loss: 0.7164, Val Accuracy: 0.3653, Precision: 0.1638, Recall: 0.9146, F1: 0.2778, AUC: 0.7318, LR: 0.0001
# Epoch 6, Train Loss: 0.7148, Validation Loss: 0.7078, Val Accuracy: 0.4150, Precision: 0.1747, Recall: 0.9085, F1: 0.2930, AUC: 0.7607, LR: 0.0001
# Epoch 7, Train Loss: 0.7060, Validation Loss: 0.6993, Val Accuracy: 0.4597, Precision: 0.1859, Recall: 0.9024, F1: 0.3083, AUC: 0.7844, LR: 0.0001
# Epoch 8, Train Loss: 0.6972, Validation Loss: 0.6908, Val Accuracy: 0.5102, Precision: 0.2000, Recall: 0.8902, F1: 0.3266, AUC: 0.8025, LR: 0.0001
# Epoch 9, Train Loss: 0.6884, Validation Loss: 0.6823, Val Accuracy: 0.5533, Precision: 0.2140, Recall: 0.8780, F1: 0.3441, AUC: 0.8164, LR: 0.0001
# Epoch 10, Train Loss: 0.6796, Validation Loss: 0.6737, Val Accuracy: 0.5899, Precision: 0.2284, Recall: 0.8720, F1: 0.3620, AUC: 0.8277, LR: 0.0001
# Epoch 11, Train Loss: 0.6708, Validation Loss: 0.6652, Val Accuracy: 0.6200, Precision: 0.2410, Recall: 0.8598, F1: 0.3765, AUC: 0.8369, LR: 0.0001
# Epoch 12, Train Loss: 0.6620, Validation Loss: 0.6566, Val Accuracy: 0.6550, Precision: 0.2566, Recall: 0.8354, F1: 0.3926, AUC: 0.8441, LR: 0.0001
# Epoch 13, Train Loss: 0.6531, Validation Loss: 0.6480, Val Accuracy: 0.6851, Precision: 0.2747, Recall: 0.8293, F1: 0.4127, AUC: 0.8506, LR: 0.0001
# Epoch 14, Train Loss: 0.6442, Validation Loss: 0.6394, Val Accuracy: 0.7120, Precision: 0.2935, Recall: 0.8232, F1: 0.4327, AUC: 0.8556, LR: 0.0001
# Epoch 15, Train Loss: 0.6352, Validation Loss: 0.6307, Val Accuracy: 0.7339, Precision: 0.3109, Recall: 0.8171, F1: 0.4504, AUC: 0.8600, LR: 0.0001
# Epoch 16, Train Loss: 0.6262, Validation Loss: 0.6219, Val Accuracy: 0.7608, Precision: 0.3359, Recall: 0.8110, F1: 0.4750, AUC: 0.8642, LR: 0.0001
# Epoch 17, Train Loss: 0.6171, Validation Loss: 0.6130, Val Accuracy: 0.7722, Precision: 0.3474, Recall: 0.8049, F1: 0.4853, AUC: 0.8677, LR: 0.0001
# Epoch 18, Train Loss: 0.6080, Validation Loss: 0.6042, Val Accuracy: 0.7925, Precision: 0.3718, Recall: 0.8049, F1: 0.5087, AUC: 0.8714, LR: 0.0001
# Epoch 19, Train Loss: 0.5989, Validation Loss: 0.5952, Val Accuracy: 0.8055, Precision: 0.3887, Recall: 0.7988, F1: 0.5230, AUC: 0.8745, LR: 0.0001
# Epoch 20, Train Loss: 0.5897, Validation Loss: 0.5862, Val Accuracy: 0.8251, Precision: 0.4180, Recall: 0.7927, F1: 0.5474, AUC: 0.8777, LR: 0.0001
# Epoch 21, Train Loss: 0.5805, Validation Loss: 0.5773, Val Accuracy: 0.8413, Precision: 0.4464, Recall: 0.7866, F1: 0.5695, AUC: 0.8802, LR: 0.0001
# Epoch 22, Train Loss: 0.5713, Validation Loss: 0.5683, Val Accuracy: 0.8511, Precision: 0.4655, Recall: 0.7805, F1: 0.5831, AUC: 0.8827, LR: 0.0001
# Epoch 23, Train Loss: 0.5621, Validation Loss: 0.5593, Val Accuracy: 0.8560, Precision: 0.4749, Recall: 0.7500, F1: 0.5816, AUC: 0.8849, LR: 0.0001
# Epoch 24, Train Loss: 0.5529, Validation Loss: 0.5503, Val Accuracy: 0.8617, Precision: 0.4880, Recall: 0.7439, F1: 0.5894, AUC: 0.8870, LR: 0.0001
# Epoch 25, Train Loss: 0.5437, Validation Loss: 0.5413, Val Accuracy: 0.8706, Precision: 0.5106, Recall: 0.7317, F1: 0.6015, AUC: 0.8890, LR: 0.0001
# Epoch 26, Train Loss: 0.5345, Validation Loss: 0.5324, Val Accuracy: 0.8763, Precision: 0.5268, Recall: 0.7195, F1: 0.6082, AUC: 0.8911, LR: 0.0001
# Epoch 27, Train Loss: 0.5254, Validation Loss: 0.5235, Val Accuracy: 0.8845, Precision: 0.5519, Recall: 0.7134, F1: 0.6223, AUC: 0.8930, LR: 0.0001
# Epoch 28, Train Loss: 0.5163, Validation Loss: 0.5146, Val Accuracy: 0.8950, Precision: 0.5897, Recall: 0.7012, F1: 0.6407, AUC: 0.8948, LR: 0.0001
# Epoch 29, Train Loss: 0.5073, Validation Loss: 0.5058, Val Accuracy: 0.8991, Precision: 0.6087, Recall: 0.6829, F1: 0.6437, AUC: 0.8966, LR: 0.0001
# Epoch 30, Train Loss: 0.4983, Validation Loss: 0.4970, Val Accuracy: 0.9015, Precision: 0.6188, Recall: 0.6829, F1: 0.6493, AUC: 0.8983, LR: 0.0001
# Epoch 31, Train Loss: 0.4894, Validation Loss: 0.4884, Val Accuracy: 0.9007, Precision: 0.6193, Recall: 0.6646, F1: 0.6412, AUC: 0.9002, LR: 0.0001
# Epoch 32, Train Loss: 0.4806, Validation Loss: 0.4798, Val Accuracy: 0.9015, Precision: 0.6243, Recall: 0.6585, F1: 0.6409, AUC: 0.9020, LR: 0.0001
# Epoch 33, Train Loss: 0.4719, Validation Loss: 0.4713, Val Accuracy: 0.9064, Precision: 0.6467, Recall: 0.6585, F1: 0.6526, AUC: 0.9034, LR: 0.0001
# Epoch 34, Train Loss: 0.4633, Validation Loss: 0.4630, Val Accuracy: 0.9064, Precision: 0.6503, Recall: 0.6463, F1: 0.6483, AUC: 0.9052, LR: 0.0001
# Epoch 35, Train Loss: 0.4548, Validation Loss: 0.4547, Val Accuracy: 0.9097, Precision: 0.6688, Recall: 0.6402, F1: 0.6542, AUC: 0.9066, LR: 0.0001
# Epoch 36, Train Loss: 0.4465, Validation Loss: 0.4466, Val Accuracy: 0.9113, Precision: 0.6774, Recall: 0.6402, F1: 0.6583, AUC: 0.9082, LR: 0.0001
# Epoch 37, Train Loss: 0.4382, Validation Loss: 0.4385, Val Accuracy: 0.9097, Precision: 0.6779, Recall: 0.6159, F1: 0.6454, AUC: 0.9097, LR: 0.0001
# Epoch 38, Train Loss: 0.4301, Validation Loss: 0.4306, Val Accuracy: 0.9113, Precision: 0.6897, Recall: 0.6098, F1: 0.6472, AUC: 0.9111, LR: 0.0001
# Epoch 39, Train Loss: 0.4221, Validation Loss: 0.4229, Val Accuracy: 0.9113, Precision: 0.6923, Recall: 0.6037, F1: 0.6450, AUC: 0.9125, LR: 0.0001
# Epoch 40, Train Loss: 0.4142, Validation Loss: 0.4152, Val Accuracy: 0.9129, Precision: 0.7021, Recall: 0.6037, F1: 0.6492, AUC: 0.9142, LR: 0.0001
# Epoch 41, Train Loss: 0.4065, Validation Loss: 0.4077, Val Accuracy: 0.9138, Precision: 0.7071, Recall: 0.6037, F1: 0.6513, AUC: 0.9157, LR: 0.0001
# Epoch 42, Train Loss: 0.3989, Validation Loss: 0.4004, Val Accuracy: 0.9129, Precision: 0.7080, Recall: 0.5915, F1: 0.6445, AUC: 0.9172, LR: 0.0001
# Epoch 43, Train Loss: 0.3915, Validation Loss: 0.3932, Val Accuracy: 0.9129, Precision: 0.7080, Recall: 0.5915, F1: 0.6445, AUC: 0.9190, LR: 0.0001
# Epoch 44, Train Loss: 0.3842, Validation Loss: 0.3861, Val Accuracy: 0.9138, Precision: 0.7132, Recall: 0.5915, F1: 0.6467, AUC: 0.9204, LR: 0.0001
# Epoch 45, Train Loss: 0.3771, Validation Loss: 0.3792, Val Accuracy: 0.9129, Precision: 0.7111, Recall: 0.5854, F1: 0.6421, AUC: 0.9220, LR: 0.0001
# Epoch 46, Train Loss: 0.3701, Validation Loss: 0.3725, Val Accuracy: 0.9162, Precision: 0.7259, Recall: 0.5976, F1: 0.6555, AUC: 0.9235, LR: 0.0001
# Epoch 47, Train Loss: 0.3633, Validation Loss: 0.3659, Val Accuracy: 0.9170, Precision: 0.7279, Recall: 0.6037, F1: 0.6600, AUC: 0.9253, LR: 0.0001
# Epoch 48, Train Loss: 0.3567, Validation Loss: 0.3594, Val Accuracy: 0.9170, Precision: 0.7279, Recall: 0.6037, F1: 0.6600, AUC: 0.9270, LR: 0.0001
# Epoch 49, Train Loss: 0.3501, Validation Loss: 0.3531, Val Accuracy: 0.9170, Precision: 0.7313, Recall: 0.5976, F1: 0.6577, AUC: 0.9285, LR: 0.0001
# Epoch 50, Train Loss: 0.3438, Validation Loss: 0.3469, Val Accuracy: 0.9170, Precision: 0.7313, Recall: 0.5976, F1: 0.6577, AUC: 0.9300, LR: 0.0001
# Epoch 51, Train Loss: 0.3376, Validation Loss: 0.3409, Val Accuracy: 0.9170, Precision: 0.7313, Recall: 0.5976, F1: 0.6577, AUC: 0.9313, LR: 0.0001
# Epoch 52, Train Loss: 0.3315, Validation Loss: 0.3351, Val Accuracy: 0.9178, Precision: 0.7368, Recall: 0.5976, F1: 0.6599, AUC: 0.9329, LR: 0.0001
# Epoch 53, Train Loss: 0.3256, Validation Loss: 0.3294, Val Accuracy: 0.9186, Precision: 0.7424, Recall: 0.5976, F1: 0.6622, AUC: 0.9347, LR: 0.0001
# Epoch 54, Train Loss: 0.3198, Validation Loss: 0.3238, Val Accuracy: 0.9203, Precision: 0.7538, Recall: 0.5976, F1: 0.6667, AUC: 0.9362, LR: 0.0001
# Epoch 55, Train Loss: 0.3142, Validation Loss: 0.3183, Val Accuracy: 0.9219, Precision: 0.7656, Recall: 0.5976, F1: 0.6712, AUC: 0.9376, LR: 0.0001
# Epoch 56, Train Loss: 0.3087, Validation Loss: 0.3130, Val Accuracy: 0.9235, Precision: 0.7734, Recall: 0.6037, F1: 0.6781, AUC: 0.9392, LR: 0.0001
# Epoch 57, Train Loss: 0.3033, Validation Loss: 0.3078, Val Accuracy: 0.9235, Precision: 0.7734, Recall: 0.6037, F1: 0.6781, AUC: 0.9407, LR: 0.0001
# Epoch 58, Train Loss: 0.2981, Validation Loss: 0.3028, Val Accuracy: 0.9251, Precision: 0.7812, Recall: 0.6098, F1: 0.6849, AUC: 0.9426, LR: 0.0001
# Epoch 59, Train Loss: 0.2930, Validation Loss: 0.2979, Val Accuracy: 0.9276, Precision: 0.7863, Recall: 0.6280, F1: 0.6983, AUC: 0.9440, LR: 0.0001
# Epoch 60, Train Loss: 0.2880, Validation Loss: 0.2931, Val Accuracy: 0.9300, Precision: 0.7955, Recall: 0.6402, F1: 0.7095, AUC: 0.9457, LR: 0.0001
# Epoch 61, Train Loss: 0.2832, Validation Loss: 0.2884, Val Accuracy: 0.9317, Precision: 0.8030, Recall: 0.6463, F1: 0.7162, AUC: 0.9473, LR: 0.0001
# Epoch 62, Train Loss: 0.2785, Validation Loss: 0.2839, Val Accuracy: 0.9357, Precision: 0.8148, Recall: 0.6707, F1: 0.7358, AUC: 0.9489, LR: 0.0001
# Epoch 63, Train Loss: 0.2739, Validation Loss: 0.2795, Val Accuracy: 0.9382, Precision: 0.8235, Recall: 0.6829, F1: 0.7467, AUC: 0.9504, LR: 0.0001
# Epoch 64, Train Loss: 0.2695, Validation Loss: 0.2752, Val Accuracy: 0.9398, Precision: 0.8261, Recall: 0.6951, F1: 0.7550, AUC: 0.9518, LR: 0.0001
# Epoch 65, Train Loss: 0.2651, Validation Loss: 0.2710, Val Accuracy: 0.9406, Precision: 0.8273, Recall: 0.7012, F1: 0.7591, AUC: 0.9531, LR: 0.0001
# Epoch 66, Train Loss: 0.2609, Validation Loss: 0.2669, Val Accuracy: 0.9422, Precision: 0.8298, Recall: 0.7134, F1: 0.7672, AUC: 0.9543, LR: 0.0001
# Epoch 67, Train Loss: 0.2567, Validation Loss: 0.2630, Val Accuracy: 0.9430, Precision: 0.8310, Recall: 0.7195, F1: 0.7712, AUC: 0.9555, LR: 0.0001
# Epoch 68, Train Loss: 0.2527, Validation Loss: 0.2591, Val Accuracy: 0.9430, Precision: 0.8310, Recall: 0.7195, F1: 0.7712, AUC: 0.9566, LR: 0.0001
# Epoch 69, Train Loss: 0.2488, Validation Loss: 0.2553, Val Accuracy: 0.9439, Precision: 0.8322, Recall: 0.7256, F1: 0.7752, AUC: 0.9576, LR: 0.0001
# Epoch 70, Train Loss: 0.2450, Validation Loss: 0.2517, Val Accuracy: 0.9430, Precision: 0.8264, Recall: 0.7256, F1: 0.7727, AUC: 0.9586, LR: 0.0001
# Epoch 71, Train Loss: 0.2413, Validation Loss: 0.2481, Val Accuracy: 0.9439, Precision: 0.8276, Recall: 0.7317, F1: 0.7767, AUC: 0.9596, LR: 0.0001
# Epoch 72, Train Loss: 0.2377, Validation Loss: 0.2446, Val Accuracy: 0.9447, Precision: 0.8333, Recall: 0.7317, F1: 0.7792, AUC: 0.9605, LR: 0.0001
# Epoch 73, Train Loss: 0.2341, Validation Loss: 0.2412, Val Accuracy: 0.9447, Precision: 0.8333, Recall: 0.7317, F1: 0.7792, AUC: 0.9613, LR: 0.0001
# Epoch 74, Train Loss: 0.2307, Validation Loss: 0.2379, Val Accuracy: 0.9455, Precision: 0.8345, Recall: 0.7378, F1: 0.7832, AUC: 0.9620, LR: 0.0001
# Epoch 75, Train Loss: 0.2274, Validation Loss: 0.2347, Val Accuracy: 0.9463, Precision: 0.8403, Recall: 0.7378, F1: 0.7857, AUC: 0.9628, LR: 0.0001
# Epoch 76, Train Loss: 0.2241, Validation Loss: 0.2316, Val Accuracy: 0.9463, Precision: 0.8403, Recall: 0.7378, F1: 0.7857, AUC: 0.9635, LR: 0.0001
# Epoch 77, Train Loss: 0.2209, Validation Loss: 0.2285, Val Accuracy: 0.9471, Precision: 0.8414, Recall: 0.7439, F1: 0.7896, AUC: 0.9644, LR: 0.0001
# Epoch 78, Train Loss: 0.2178, Validation Loss: 0.2255, Val Accuracy: 0.9471, Precision: 0.8414, Recall: 0.7439, F1: 0.7896, AUC: 0.9651, LR: 0.0001
# Epoch 79, Train Loss: 0.2148, Validation Loss: 0.2226, Val Accuracy: 0.9471, Precision: 0.8414, Recall: 0.7439, F1: 0.7896, AUC: 0.9658, LR: 0.0001
# Epoch 80, Train Loss: 0.2118, Validation Loss: 0.2198, Val Accuracy: 0.9479, Precision: 0.8425, Recall: 0.7500, F1: 0.7935, AUC: 0.9664, LR: 0.0001
# Epoch 81, Train Loss: 0.2090, Validation Loss: 0.2170, Val Accuracy: 0.9487, Precision: 0.8435, Recall: 0.7561, F1: 0.7974, AUC: 0.9671, LR: 0.0001
# Epoch 82, Train Loss: 0.2062, Validation Loss: 0.2143, Val Accuracy: 0.9487, Precision: 0.8435, Recall: 0.7561, F1: 0.7974, AUC: 0.9678, LR: 0.0001
# Epoch 83, Train Loss: 0.2034, Validation Loss: 0.2117, Val Accuracy: 0.9487, Precision: 0.8435, Recall: 0.7561, F1: 0.7974, AUC: 0.9684, LR: 0.0001
# Epoch 84, Train Loss: 0.2008, Validation Loss: 0.2091, Val Accuracy: 0.9496, Precision: 0.8446, Recall: 0.7622, F1: 0.8013, AUC: 0.9690, LR: 0.0001
# Epoch 85, Train Loss: 0.1982, Validation Loss: 0.2066, Val Accuracy: 0.9504, Precision: 0.8411, Recall: 0.7744, F1: 0.8063, AUC: 0.9695, LR: 0.0001
# Epoch 86, Train Loss: 0.1956, Validation Loss: 0.2042, Val Accuracy: 0.9504, Precision: 0.8411, Recall: 0.7744, F1: 0.8063, AUC: 0.9701, LR: 0.0001
# Epoch 87, Train Loss: 0.1931, Validation Loss: 0.2018, Val Accuracy: 0.9520, Precision: 0.8431, Recall: 0.7866, F1: 0.8139, AUC: 0.9706, LR: 0.0001
# Epoch 88, Train Loss: 0.1907, Validation Loss: 0.1994, Val Accuracy: 0.9520, Precision: 0.8431, Recall: 0.7866, F1: 0.8139, AUC: 0.9710, LR: 0.0001
# Epoch 89, Train Loss: 0.1883, Validation Loss: 0.1972, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9715, LR: 0.0001
# Epoch 90, Train Loss: 0.1860, Validation Loss: 0.1949, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9719, LR: 0.0001
# Epoch 91, Train Loss: 0.1837, Validation Loss: 0.1927, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9724, LR: 0.0001
# Epoch 92, Train Loss: 0.1815, Validation Loss: 0.1906, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9728, LR: 0.0001
# Epoch 93, Train Loss: 0.1793, Validation Loss: 0.1885, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9732, LR: 0.0001
# Epoch 94, Train Loss: 0.1772, Validation Loss: 0.1865, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9736, LR: 0.0001
# Epoch 95, Train Loss: 0.1751, Validation Loss: 0.1845, Val Accuracy: 0.9512, Precision: 0.8421, Recall: 0.7805, F1: 0.8101, AUC: 0.9741, LR: 0.0001
# Epoch 96, Train Loss: 0.1731, Validation Loss: 0.1825, Val Accuracy: 0.9528, Precision: 0.8533, Recall: 0.7805, F1: 0.8153, AUC: 0.9745, LR: 0.0001
# Epoch 97, Train Loss: 0.1711, Validation Loss: 0.1806, Val Accuracy: 0.9528, Precision: 0.8533, Recall: 0.7805, F1: 0.8153, AUC: 0.9750, LR: 0.0001
# Epoch 98, Train Loss: 0.1692, Validation Loss: 0.1788, Val Accuracy: 0.9544, Precision: 0.8600, Recall: 0.7866, F1: 0.8217, AUC: 0.9753, LR: 0.0001
# Epoch 99, Train Loss: 0.1673, Validation Loss: 0.1769, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9757, LR: 0.0001
# Epoch 100, Train Loss: 0.1654, Validation Loss: 0.1751, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9761, LR: 0.0001
# Epoch 101, Train Loss: 0.1636, Validation Loss: 0.1734, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9765, LR: 0.0001
# Epoch 102, Train Loss: 0.1618, Validation Loss: 0.1717, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9768, LR: 0.0001
# Epoch 103, Train Loss: 0.1600, Validation Loss: 0.1700, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9771, LR: 0.0001
# Epoch 104, Train Loss: 0.1583, Validation Loss: 0.1683, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9774, LR: 0.0001
# Epoch 105, Train Loss: 0.1566, Validation Loss: 0.1667, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9778, LR: 0.0001
# Epoch 106, Train Loss: 0.1550, Validation Loss: 0.1651, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9781, LR: 0.0001
# Epoch 107, Train Loss: 0.1534, Validation Loss: 0.1636, Val Accuracy: 0.9552, Precision: 0.8609, Recall: 0.7927, F1: 0.8254, AUC: 0.9784, LR: 0.0001
# Epoch 108, Train Loss: 0.1518, Validation Loss: 0.1621, Val Accuracy: 0.9561, Precision: 0.8667, Recall: 0.7927, F1: 0.8280, AUC: 0.9787, LR: 0.0001
# Epoch 109, Train Loss: 0.1502, Validation Loss: 0.1606, Val Accuracy: 0.9561, Precision: 0.8667, Recall: 0.7927, F1: 0.8280, AUC: 0.9789, LR: 0.0001
# Epoch 110, Train Loss: 0.1487, Validation Loss: 0.1591, Val Accuracy: 0.9569, Precision: 0.8675, Recall: 0.7988, F1: 0.8317, AUC: 0.9791, LR: 0.0001
# Epoch 111, Train Loss: 0.1472, Validation Loss: 0.1577, Val Accuracy: 0.9569, Precision: 0.8675, Recall: 0.7988, F1: 0.8317, AUC: 0.9794, LR: 0.0001
# Epoch 112, Train Loss: 0.1458, Validation Loss: 0.1563, Val Accuracy: 0.9569, Precision: 0.8675, Recall: 0.7988, F1: 0.8317, AUC: 0.9796, LR: 0.0001
# Epoch 113, Train Loss: 0.1443, Validation Loss: 0.1549, Val Accuracy: 0.9577, Precision: 0.8684, Recall: 0.8049, F1: 0.8354, AUC: 0.9798, LR: 0.0001
# Epoch 114, Train Loss: 0.1429, Validation Loss: 0.1535, Val Accuracy: 0.9593, Precision: 0.8701, Recall: 0.8171, F1: 0.8428, AUC: 0.9801, LR: 0.0001
# Epoch 115, Train Loss: 0.1415, Validation Loss: 0.1522, Val Accuracy: 0.9593, Precision: 0.8701, Recall: 0.8171, F1: 0.8428, AUC: 0.9804, LR: 0.0001
# Epoch 116, Train Loss: 0.1402, Validation Loss: 0.1509, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9806, LR: 0.0001
# Epoch 117, Train Loss: 0.1389, Validation Loss: 0.1496, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9808, LR: 0.0001
# Epoch 118, Train Loss: 0.1376, Validation Loss: 0.1484, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9811, LR: 0.0001
# Epoch 119, Train Loss: 0.1363, Validation Loss: 0.1471, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9813, LR: 0.0001
# Epoch 120, Train Loss: 0.1350, Validation Loss: 0.1459, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9816, LR: 0.0001
# Epoch 121, Train Loss: 0.1338, Validation Loss: 0.1447, Val Accuracy: 0.9601, Precision: 0.8758, Recall: 0.8171, F1: 0.8454, AUC: 0.9818, LR: 0.0001
# Epoch 122, Train Loss: 0.1326, Validation Loss: 0.1436, Val Accuracy: 0.9609, Precision: 0.8766, Recall: 0.8232, F1: 0.8491, AUC: 0.9820, LR: 0.0001
# Epoch 123, Train Loss: 0.1314, Validation Loss: 0.1424, Val Accuracy: 0.9618, Precision: 0.8774, Recall: 0.8293, F1: 0.8527, AUC: 0.9822, LR: 0.0001
# Epoch 124, Train Loss: 0.1302, Validation Loss: 0.1413, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9825, LR: 0.0001
# Epoch 125, Train Loss: 0.1290, Validation Loss: 0.1402, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9826, LR: 0.0001
# Epoch 126, Train Loss: 0.1279, Validation Loss: 0.1391, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9828, LR: 0.0001
# Epoch 127, Train Loss: 0.1268, Validation Loss: 0.1380, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9830, LR: 0.0001
# Epoch 128, Train Loss: 0.1257, Validation Loss: 0.1370, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9833, LR: 0.0001
# Epoch 129, Train Loss: 0.1246, Validation Loss: 0.1359, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9835, LR: 0.0001
# Epoch 130, Train Loss: 0.1236, Validation Loss: 0.1349, Val Accuracy: 0.9626, Precision: 0.8831, Recall: 0.8293, F1: 0.8553, AUC: 0.9837, LR: 0.0001
# Epoch 131, Train Loss: 0.1225, Validation Loss: 0.1339, Val Accuracy: 0.9634, Precision: 0.8889, Recall: 0.8293, F1: 0.8580, AUC: 0.9839, LR: 0.0001
# Epoch 132, Train Loss: 0.1215, Validation Loss: 0.1330, Val Accuracy: 0.9634, Precision: 0.8839, Recall: 0.8354, F1: 0.8589, AUC: 0.9841, LR: 0.0001
# Epoch 133, Train Loss: 0.1205, Validation Loss: 0.1320, Val Accuracy: 0.9634, Precision: 0.8839, Recall: 0.8354, F1: 0.8589, AUC: 0.9842, LR: 0.0001
# Epoch 134, Train Loss: 0.1195, Validation Loss: 0.1310, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9844, LR: 0.0001
# Epoch 135, Train Loss: 0.1186, Validation Loss: 0.1301, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9846, LR: 0.0001
# Epoch 136, Train Loss: 0.1176, Validation Loss: 0.1292, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9847, LR: 0.0001
# Epoch 137, Train Loss: 0.1167, Validation Loss: 0.1283, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9849, LR: 0.0001
# Epoch 138, Train Loss: 0.1157, Validation Loss: 0.1274, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9851, LR: 0.0001
# Epoch 139, Train Loss: 0.1148, Validation Loss: 0.1265, Val Accuracy: 0.9642, Precision: 0.8846, Recall: 0.8415, F1: 0.8625, AUC: 0.9852, LR: 0.0001
# Epoch 140, Train Loss: 0.1139, Validation Loss: 0.1257, Val Accuracy: 0.9650, Precision: 0.8903, Recall: 0.8415, F1: 0.8652, AUC: 0.9853, LR: 0.0001
# Epoch 141, Train Loss: 0.1131, Validation Loss: 0.1248, Val Accuracy: 0.9650, Precision: 0.8903, Recall: 0.8415, F1: 0.8652, AUC: 0.9855, LR: 0.0001
# Epoch 142, Train Loss: 0.1122, Validation Loss: 0.1240, Val Accuracy: 0.9650, Precision: 0.8903, Recall: 0.8415, F1: 0.8652, AUC: 0.9856, LR: 0.0001
# Epoch 143, Train Loss: 0.1113, Validation Loss: 0.1232, Val Accuracy: 0.9650, Precision: 0.8903, Recall: 0.8415, F1: 0.8652, AUC: 0.9858, LR: 0.0001
# Epoch 144, Train Loss: 0.1105, Validation Loss: 0.1224, Val Accuracy: 0.9658, Precision: 0.8910, Recall: 0.8476, F1: 0.8688, AUC: 0.9860, LR: 0.0001
# Epoch 145, Train Loss: 0.1097, Validation Loss: 0.1216, Val Accuracy: 0.9658, Precision: 0.8910, Recall: 0.8476, F1: 0.8688, AUC: 0.9861, LR: 0.0001
# Epoch 146, Train Loss: 0.1088, Validation Loss: 0.1208, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9863, LR: 0.0001
# Epoch 147, Train Loss: 0.1080, Validation Loss: 0.1200, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9865, LR: 0.0001
# Epoch 148, Train Loss: 0.1072, Validation Loss: 0.1192, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9866, LR: 0.0001
# Epoch 149, Train Loss: 0.1065, Validation Loss: 0.1185, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9867, LR: 0.0001
# Epoch 150, Train Loss: 0.1057, Validation Loss: 0.1177, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9869, LR: 0.0001
# Epoch 151, Train Loss: 0.1049, Validation Loss: 0.1170, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9870, LR: 0.0001
# Epoch 152, Train Loss: 0.1042, Validation Loss: 0.1163, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9871, LR: 0.0001
# Epoch 153, Train Loss: 0.1035, Validation Loss: 0.1156, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9873, LR: 0.0001
# Epoch 154, Train Loss: 0.1027, Validation Loss: 0.1149, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9875, LR: 0.0001
# Epoch 155, Train Loss: 0.1020, Validation Loss: 0.1142, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9876, LR: 0.0001
# Epoch 156, Train Loss: 0.1013, Validation Loss: 0.1135, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9877, LR: 0.0001
# Epoch 157, Train Loss: 0.1006, Validation Loss: 0.1128, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9878, LR: 0.0001
# Epoch 158, Train Loss: 0.0999, Validation Loss: 0.1122, Val Accuracy: 0.9666, Precision: 0.8917, Recall: 0.8537, F1: 0.8723, AUC: 0.9879, LR: 0.0001
# Epoch 159, Train Loss: 0.0992, Validation Loss: 0.1115, Val Accuracy: 0.9675, Precision: 0.8974, Recall: 0.8537, F1: 0.8750, AUC: 0.9881, LR: 0.0001
# Epoch 160, Train Loss: 0.0986, Validation Loss: 0.1109, Val Accuracy: 0.9675, Precision: 0.8974, Recall: 0.8537, F1: 0.8750, AUC: 0.9882, LR: 0.0001
# Epoch 161, Train Loss: 0.0979, Validation Loss: 0.1102, Val Accuracy: 0.9683, Precision: 0.8981, Recall: 0.8598, F1: 0.8785, AUC: 0.9883, LR: 0.0001
# Epoch 162, Train Loss: 0.0973, Validation Loss: 0.1096, Val Accuracy: 0.9683, Precision: 0.8981, Recall: 0.8598, F1: 0.8785, AUC: 0.9885, LR: 0.0001
# Epoch 163, Train Loss: 0.0966, Validation Loss: 0.1090, Val Accuracy: 0.9683, Precision: 0.8981, Recall: 0.8598, F1: 0.8785, AUC: 0.9886, LR: 0.0001
# Epoch 164, Train Loss: 0.0960, Validation Loss: 0.1084, Val Accuracy: 0.9683, Precision: 0.8981, Recall: 0.8598, F1: 0.8785, AUC: 0.9887, LR: 0.0001
# Epoch 165, Train Loss: 0.0954, Validation Loss: 0.1078, Val Accuracy: 0.9691, Precision: 0.8987, Recall: 0.8659, F1: 0.8820, AUC: 0.9889, LR: 0.0001
# Epoch 166, Train Loss: 0.0947, Validation Loss: 0.1072, Val Accuracy: 0.9691, Precision: 0.8987, Recall: 0.8659, F1: 0.8820, AUC: 0.9890, LR: 0.0001
# Epoch 167, Train Loss: 0.0941, Validation Loss: 0.1066, Val Accuracy: 0.9691, Precision: 0.8987, Recall: 0.8659, F1: 0.8820, AUC: 0.9892, LR: 0.0001
# Epoch 168, Train Loss: 0.0935, Validation Loss: 0.1060, Val Accuracy: 0.9691, Precision: 0.8987, Recall: 0.8659, F1: 0.8820, AUC: 0.9893, LR: 0.0001
# Epoch 169, Train Loss: 0.0929, Validation Loss: 0.1054, Val Accuracy: 0.9699, Precision: 0.8994, Recall: 0.8720, F1: 0.8854, AUC: 0.9894, LR: 0.0001
# Epoch 170, Train Loss: 0.0924, Validation Loss: 0.1049, Val Accuracy: 0.9707, Precision: 0.9051, Recall: 0.8720, F1: 0.8882, AUC: 0.9895, LR: 0.0001
# Epoch 171, Train Loss: 0.0918, Validation Loss: 0.1043, Val Accuracy: 0.9707, Precision: 0.9051, Recall: 0.8720, F1: 0.8882, AUC: 0.9896, LR: 0.0001
# Epoch 172, Train Loss: 0.0912, Validation Loss: 0.1038, Val Accuracy: 0.9707, Precision: 0.9051, Recall: 0.8720, F1: 0.8882, AUC: 0.9897, LR: 0.0001
# Epoch 173, Train Loss: 0.0906, Validation Loss: 0.1032, Val Accuracy: 0.9707, Precision: 0.9051, Recall: 0.8720, F1: 0.8882, AUC: 0.9898, LR: 0.0001
# Epoch 174, Train Loss: 0.0901, Validation Loss: 0.1027, Val Accuracy: 0.9707, Precision: 0.9051, Recall: 0.8720, F1: 0.8882, AUC: 0.9899, LR: 0.0001
# Epoch 175, Train Loss: 0.0895, Validation Loss: 0.1022, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9900, LR: 0.0001
# Epoch 176, Train Loss: 0.0890, Validation Loss: 0.1016, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9901, LR: 0.0001
# Epoch 177, Train Loss: 0.0885, Validation Loss: 0.1011, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9902, LR: 0.0001
# Epoch 178, Train Loss: 0.0879, Validation Loss: 0.1006, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9903, LR: 0.0001
# Epoch 179, Train Loss: 0.0874, Validation Loss: 0.1001, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9904, LR: 0.0001
# Epoch 180, Train Loss: 0.0869, Validation Loss: 0.0996, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9904, LR: 0.0001
# Epoch 181, Train Loss: 0.0864, Validation Loss: 0.0991, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9905, LR: 0.0001
# Epoch 182, Train Loss: 0.0859, Validation Loss: 0.0986, Val Accuracy: 0.9715, Precision: 0.9057, Recall: 0.8780, F1: 0.8916, AUC: 0.9906, LR: 0.0001
# Epoch 183, Train Loss: 0.0854, Validation Loss: 0.0981, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9907, LR: 0.0001
# Epoch 184, Train Loss: 0.0849, Validation Loss: 0.0976, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9908, LR: 0.0001
# Epoch 185, Train Loss: 0.0844, Validation Loss: 0.0972, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9909, LR: 0.0001
# Epoch 186, Train Loss: 0.0839, Validation Loss: 0.0967, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9909, LR: 0.0001
# Epoch 187, Train Loss: 0.0834, Validation Loss: 0.0962, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9910, LR: 0.0001
# Epoch 188, Train Loss: 0.0829, Validation Loss: 0.0958, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9911, LR: 0.0001
# Epoch 189, Train Loss: 0.0825, Validation Loss: 0.0953, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9912, LR: 0.0001
# Epoch 190, Train Loss: 0.0820, Validation Loss: 0.0949, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9913, LR: 0.0001
# Epoch 191, Train Loss: 0.0816, Validation Loss: 0.0944, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9913, LR: 0.0001
# Epoch 192, Train Loss: 0.0811, Validation Loss: 0.0940, Val Accuracy: 0.9731, Precision: 0.9119, Recall: 0.8841, F1: 0.8978, AUC: 0.9914, LR: 0.0001
# Epoch 193, Train Loss: 0.0807, Validation Loss: 0.0936, Val Accuracy: 0.9740, Precision: 0.9125, Recall: 0.8902, F1: 0.9012, AUC: 0.9915, LR: 0.0001
# Epoch 194, Train Loss: 0.0802, Validation Loss: 0.0931, Val Accuracy: 0.9740, Precision: 0.9125, Recall: 0.8902, F1: 0.9012, AUC: 0.9916, LR: 0.0001
# Epoch 195, Train Loss: 0.0798, Validation Loss: 0.0927, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9917, LR: 0.0001
# Epoch 196, Train Loss: 0.0793, Validation Loss: 0.0923, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9918, LR: 0.0001
# Epoch 197, Train Loss: 0.0789, Validation Loss: 0.0919, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9918, LR: 0.0001
# Epoch 198, Train Loss: 0.0785, Validation Loss: 0.0915, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9919, LR: 0.0001
# Epoch 199, Train Loss: 0.0781, Validation Loss: 0.0910, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9920, LR: 0.0001
# Epoch 200, Train Loss: 0.0776, Validation Loss: 0.0906, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9920, LR: 0.0001
# Epoch 201, Train Loss: 0.0772, Validation Loss: 0.0902, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9921, LR: 0.0001
# Epoch 202, Train Loss: 0.0768, Validation Loss: 0.0898, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9921, LR: 0.0001
# Epoch 203, Train Loss: 0.0764, Validation Loss: 0.0895, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9922, LR: 0.0001
# Epoch 204, Train Loss: 0.0760, Validation Loss: 0.0891, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9923, LR: 0.0001
# Epoch 205, Train Loss: 0.0756, Validation Loss: 0.0887, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9923, LR: 0.0001
# Epoch 206, Train Loss: 0.0752, Validation Loss: 0.0883, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9924, LR: 0.0001
# Epoch 207, Train Loss: 0.0748, Validation Loss: 0.0879, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9924, LR: 0.0001
# Epoch 208, Train Loss: 0.0744, Validation Loss: 0.0876, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9925, LR: 0.0001
# Epoch 209, Train Loss: 0.0740, Validation Loss: 0.0872, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9925, LR: 0.0001
# Epoch 210, Train Loss: 0.0736, Validation Loss: 0.0868, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9926, LR: 0.0001
# Epoch 211, Train Loss: 0.0733, Validation Loss: 0.0864, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9926, LR: 0.0001
# Epoch 212, Train Loss: 0.0729, Validation Loss: 0.0861, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9927, LR: 0.0001
# Epoch 213, Train Loss: 0.0725, Validation Loss: 0.0857, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9927, LR: 0.0001
# Epoch 214, Train Loss: 0.0721, Validation Loss: 0.0854, Val Accuracy: 0.9748, Precision: 0.9130, Recall: 0.8963, F1: 0.9046, AUC: 0.9928, LR: 0.0001
# Epoch 215, Train Loss: 0.0718, Validation Loss: 0.0850, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9928, LR: 0.0001
# Epoch 216, Train Loss: 0.0714, Validation Loss: 0.0847, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9928, LR: 0.0001
# Epoch 217, Train Loss: 0.0711, Validation Loss: 0.0843, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9929, LR: 0.0001
# Epoch 218, Train Loss: 0.0707, Validation Loss: 0.0840, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9930, LR: 0.0001
# Epoch 219, Train Loss: 0.0703, Validation Loss: 0.0836, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9930, LR: 0.0001
# Epoch 220, Train Loss: 0.0700, Validation Loss: 0.0833, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9931, LR: 0.0001
# Epoch 221, Train Loss: 0.0696, Validation Loss: 0.0830, Val Accuracy: 0.9756, Precision: 0.9187, Recall: 0.8963, F1: 0.9074, AUC: 0.9932, LR: 0.0001
# Epoch 222, Train Loss: 0.0693, Validation Loss: 0.0826, Val Accuracy: 0.9764, Precision: 0.9193, Recall: 0.9024, F1: 0.9108, AUC: 0.9932, LR: 0.0001
# Epoch 223, Train Loss: 0.0690, Validation Loss: 0.0823, Val Accuracy: 0.9764, Precision: 0.9193, Recall: 0.9024, F1: 0.9108, AUC: 0.9933, LR: 0.0001
# Epoch 224, Train Loss: 0.0686, Validation Loss: 0.0820, Val Accuracy: 0.9764, Precision: 0.9193, Recall: 0.9024, F1: 0.9108, AUC: 0.9933, LR: 0.0001
# Epoch 225, Train Loss: 0.0683, Validation Loss: 0.0816, Val Accuracy: 0.9764, Precision: 0.9193, Recall: 0.9024, F1: 0.9108, AUC: 0.9934, LR: 0.0001
# Epoch 226, Train Loss: 0.0679, Validation Loss: 0.0813, Val Accuracy: 0.9764, Precision: 0.9193, Recall: 0.9024, F1: 0.9108, AUC: 0.9934, LR: 0.0001
# Epoch 227, Train Loss: 0.0676, Validation Loss: 0.0810, Val Accuracy: 0.9772, Precision: 0.9198, Recall: 0.9085, F1: 0.9141, AUC: 0.9934, LR: 0.0001
# Epoch 228, Train Loss: 0.0673, Validation Loss: 0.0807, Val Accuracy: 0.9772, Precision: 0.9198, Recall: 0.9085, F1: 0.9141, AUC: 0.9934, LR: 0.0001
# Epoch 229, Train Loss: 0.0670, Validation Loss: 0.0804, Val Accuracy: 0.9772, Precision: 0.9198, Recall: 0.9085, F1: 0.9141, AUC: 0.9935, LR: 0.0001
# Epoch 230, Train Loss: 0.0666, Validation Loss: 0.0800, Val Accuracy: 0.9772, Precision: 0.9198, Recall: 0.9085, F1: 0.9141, AUC: 0.9936, LR: 0.0001
# Epoch 231, Train Loss: 0.0663, Validation Loss: 0.0797, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9936, LR: 0.0001
# Epoch 232, Train Loss: 0.0660, Validation Loss: 0.0794, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9937, LR: 0.0001
# Epoch 233, Train Loss: 0.0657, Validation Loss: 0.0791, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9937, LR: 0.0001
# Epoch 234, Train Loss: 0.0654, Validation Loss: 0.0788, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9937, LR: 0.0001
# Epoch 235, Train Loss: 0.0650, Validation Loss: 0.0785, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9938, LR: 0.0001
# Epoch 236, Train Loss: 0.0647, Validation Loss: 0.0782, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9938, LR: 0.0001
# Epoch 237, Train Loss: 0.0644, Validation Loss: 0.0779, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9938, LR: 0.0001
# Epoch 238, Train Loss: 0.0641, Validation Loss: 0.0776, Val Accuracy: 0.9780, Precision: 0.9202, Recall: 0.9146, F1: 0.9174, AUC: 0.9938, LR: 0.0001
# Epoch 239, Train Loss: 0.0638, Validation Loss: 0.0773, Val Accuracy: 0.9788, Precision: 0.9207, Recall: 0.9207, F1: 0.9207, AUC: 0.9939, LR: 0.0001
# Epoch 240, Train Loss: 0.0635, Validation Loss: 0.0770, Val Accuracy: 0.9788, Precision: 0.9207, Recall: 0.9207, F1: 0.9207, AUC: 0.9939, LR: 0.0001
# Epoch 241, Train Loss: 0.0632, Validation Loss: 0.0767, Val Accuracy: 0.9780, Precision: 0.9152, Recall: 0.9207, F1: 0.9179, AUC: 0.9939, LR: 0.0001
# Epoch 242, Train Loss: 0.0629, Validation Loss: 0.0764, Val Accuracy: 0.9780, Precision: 0.9152, Recall: 0.9207, F1: 0.9179, AUC: 0.9940, LR: 0.0001
# Epoch 243, Train Loss: 0.0626, Validation Loss: 0.0761, Val Accuracy: 0.9780, Precision: 0.9152, Recall: 0.9207, F1: 0.9179, AUC: 0.9940, LR: 0.0001
# Epoch 244, Train Loss: 0.0623, Validation Loss: 0.0759, Val Accuracy: 0.9797, Precision: 0.9212, Recall: 0.9268, F1: 0.9240, AUC: 0.9940, LR: 0.0001
# Epoch 245, Train Loss: 0.0621, Validation Loss: 0.0756, Val Accuracy: 0.9797, Precision: 0.9212, Recall: 0.9268, F1: 0.9240, AUC: 0.9940, LR: 0.0001
# Epoch 246, Train Loss: 0.0618, Validation Loss: 0.0753, Val Accuracy: 0.9797, Precision: 0.9212, Recall: 0.9268, F1: 0.9240, AUC: 0.9941, LR: 0.0001
# Epoch 247, Train Loss: 0.0615, Validation Loss: 0.0750, Val Accuracy: 0.9797, Precision: 0.9212, Recall: 0.9268, F1: 0.9240, AUC: 0.9941, LR: 0.0001
# Epoch 248, Train Loss: 0.0612, Validation Loss: 0.0748, Val Accuracy: 0.9797, Precision: 0.9212, Recall: 0.9268, F1: 0.9240, AUC: 0.9941, LR: 0.0001
# Epoch 249, Train Loss: 0.0609, Validation Loss: 0.0745, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9941, LR: 0.0001
# Epoch 250, Train Loss: 0.0606, Validation Loss: 0.0742, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9941, LR: 0.0001
# Epoch 251, Train Loss: 0.0604, Validation Loss: 0.0740, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9942, LR: 0.0001
# Epoch 252, Train Loss: 0.0601, Validation Loss: 0.0737, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9942, LR: 0.0001
# Epoch 253, Train Loss: 0.0598, Validation Loss: 0.0734, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9942, LR: 0.0001
# Epoch 254, Train Loss: 0.0596, Validation Loss: 0.0732, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 255, Train Loss: 0.0593, Validation Loss: 0.0729, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 256, Train Loss: 0.0590, Validation Loss: 0.0727, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 257, Train Loss: 0.0588, Validation Loss: 0.0724, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 258, Train Loss: 0.0585, Validation Loss: 0.0722, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 259, Train Loss: 0.0582, Validation Loss: 0.0719, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9943, LR: 0.0001
# Epoch 260, Train Loss: 0.0580, Validation Loss: 0.0717, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9944, LR: 0.0001
# Epoch 261, Train Loss: 0.0577, Validation Loss: 0.0715, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9944, LR: 0.0001
# Epoch 262, Train Loss: 0.0575, Validation Loss: 0.0712, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9944, LR: 0.0001
# Epoch 263, Train Loss: 0.0572, Validation Loss: 0.0710, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9944, LR: 0.0001
# Epoch 264, Train Loss: 0.0570, Validation Loss: 0.0707, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9945, LR: 0.0001
# Epoch 265, Train Loss: 0.0567, Validation Loss: 0.0705, Val Accuracy: 0.9805, Precision: 0.9217, Recall: 0.9329, F1: 0.9273, AUC: 0.9945, LR: 0.0001
# Epoch 266, Train Loss: 0.0565, Validation Loss: 0.0703, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9945, LR: 0.0001
# Epoch 267, Train Loss: 0.0562, Validation Loss: 0.0701, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9945, LR: 0.0001
# Epoch 268, Train Loss: 0.0560, Validation Loss: 0.0698, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9945, LR: 0.0001
# Epoch 269, Train Loss: 0.0558, Validation Loss: 0.0696, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9946, LR: 0.0001
# Epoch 270, Train Loss: 0.0555, Validation Loss: 0.0694, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9946, LR: 0.0001
# Epoch 271, Train Loss: 0.0553, Validation Loss: 0.0692, Val Accuracy: 0.9813, Precision: 0.9222, Recall: 0.9390, F1: 0.9305, AUC: 0.9946, LR: 0.0001
# Epoch 272, Train Loss: 0.0551, Validation Loss: 0.0689, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9946, LR: 0.0001
# Epoch 273, Train Loss: 0.0548, Validation Loss: 0.0687, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9947, LR: 0.0001
# Epoch 274, Train Loss: 0.0546, Validation Loss: 0.0685, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9947, LR: 0.0001
# Epoch 275, Train Loss: 0.0544, Validation Loss: 0.0683, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9947, LR: 0.0001
# Epoch 276, Train Loss: 0.0541, Validation Loss: 0.0681, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9947, LR: 0.0001
# Epoch 277, Train Loss: 0.0539, Validation Loss: 0.0679, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9947, LR: 0.0001
# Epoch 278, Train Loss: 0.0537, Validation Loss: 0.0677, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9948, LR: 0.0001
# Epoch 279, Train Loss: 0.0535, Validation Loss: 0.0675, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9948, LR: 0.0001
# Epoch 280, Train Loss: 0.0533, Validation Loss: 0.0673, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9948, LR: 0.0001
# Epoch 281, Train Loss: 0.0530, Validation Loss: 0.0671, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9948, LR: 0.0001
# Epoch 282, Train Loss: 0.0528, Validation Loss: 0.0669, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9948, LR: 0.0001
# Epoch 283, Train Loss: 0.0526, Validation Loss: 0.0667, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9948, LR: 0.0001
# Epoch 284, Train Loss: 0.0524, Validation Loss: 0.0665, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9949, LR: 0.0001
# Epoch 285, Train Loss: 0.0522, Validation Loss: 0.0663, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9949, LR: 0.0001
# Epoch 286, Train Loss: 0.0520, Validation Loss: 0.0661, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9949, LR: 0.0001
# Epoch 287, Train Loss: 0.0518, Validation Loss: 0.0659, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9949, LR: 0.0001
# Epoch 288, Train Loss: 0.0516, Validation Loss: 0.0657, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9949, LR: 0.0001
# Epoch 289, Train Loss: 0.0514, Validation Loss: 0.0655, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 290, Train Loss: 0.0512, Validation Loss: 0.0653, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 291, Train Loss: 0.0510, Validation Loss: 0.0651, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 292, Train Loss: 0.0508, Validation Loss: 0.0650, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 293, Train Loss: 0.0506, Validation Loss: 0.0648, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 294, Train Loss: 0.0504, Validation Loss: 0.0646, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 295, Train Loss: 0.0502, Validation Loss: 0.0644, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9950, LR: 0.0001
# Epoch 296, Train Loss: 0.0500, Validation Loss: 0.0642, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 297, Train Loss: 0.0498, Validation Loss: 0.0641, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 298, Train Loss: 0.0496, Validation Loss: 0.0639, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 299, Train Loss: 0.0494, Validation Loss: 0.0637, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 300, Train Loss: 0.0492, Validation Loss: 0.0635, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 301, Train Loss: 0.0490, Validation Loss: 0.0634, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 302, Train Loss: 0.0489, Validation Loss: 0.0632, Val Accuracy: 0.9813, Precision: 0.9273, Recall: 0.9329, F1: 0.9301, AUC: 0.9951, LR: 0.0001
# Epoch 303, Train Loss: 0.0487, Validation Loss: 0.0630, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9951, LR: 0.0001
# Epoch 304, Train Loss: 0.0485, Validation Loss: 0.0629, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9952, LR: 0.0001
# Epoch 305, Train Loss: 0.0483, Validation Loss: 0.0627, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9951, LR: 0.0001
# Epoch 306, Train Loss: 0.0481, Validation Loss: 0.0626, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9951, LR: 0.0001
# Epoch 307, Train Loss: 0.0480, Validation Loss: 0.0624, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9951, LR: 0.0001
# Epoch 308, Train Loss: 0.0478, Validation Loss: 0.0622, Val Accuracy: 0.9821, Precision: 0.9277, Recall: 0.9390, F1: 0.9333, AUC: 0.9952, LR: 0.0001
# Epoch 309, Train Loss: 0.0476, Validation Loss: 0.0621, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 310, Train Loss: 0.0474, Validation Loss: 0.0619, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 311, Train Loss: 0.0473, Validation Loss: 0.0618, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 312, Train Loss: 0.0471, Validation Loss: 0.0616, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 313, Train Loss: 0.0469, Validation Loss: 0.0615, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 314, Train Loss: 0.0468, Validation Loss: 0.0613, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 315, Train Loss: 0.0466, Validation Loss: 0.0612, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 316, Train Loss: 0.0464, Validation Loss: 0.0610, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 317, Train Loss: 0.0463, Validation Loss: 0.0609, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9952, LR: 0.0001
# Epoch 318, Train Loss: 0.0461, Validation Loss: 0.0607, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9953, LR: 0.0001
# Epoch 319, Train Loss: 0.0459, Validation Loss: 0.0606, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9953, LR: 0.0001
# Epoch 320, Train Loss: 0.0458, Validation Loss: 0.0605, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9953, LR: 0.0001
# Epoch 321, Train Loss: 0.0456, Validation Loss: 0.0603, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9953, LR: 0.0001
# Epoch 322, Train Loss: 0.0454, Validation Loss: 0.0602, Val Accuracy: 0.9829, Precision: 0.9333, Recall: 0.9390, F1: 0.9362, AUC: 0.9953, LR: 0.0001
# ...
# Epoch 394, Train Loss: 0.0363, Validation Loss: 0.0525, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9960, LR: 0.0001
# Epoch 395, Train Loss: 0.0361, Validation Loss: 0.0524, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9960, LR: 0.0001
# Epoch 396, Train Loss: 0.0360, Validation Loss: 0.0523, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 397, Train Loss: 0.0359, Validation Loss: 0.0522, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 398, Train Loss: 0.0358, Validation Loss: 0.0521, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 399, Train Loss: 0.0357, Validation Loss: 0.0521, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 400, Train Loss: 0.0356, Validation Loss: 0.0520, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 401, Train Loss: 0.0355, Validation Loss: 0.0519, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 402, Train Loss: 0.0354, Validation Loss: 0.0518, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 403, Train Loss: 0.0353, Validation Loss: 0.0517, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 404, Train Loss: 0.0352, Validation Loss: 0.0517, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 405, Train Loss: 0.0351, Validation Loss: 0.0516, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9960, LR: 0.0001
# Epoch 406, Train Loss: 0.0350, Validation Loss: 0.0515, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 407, Train Loss: 0.0349, Validation Loss: 0.0514, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 408, Train Loss: 0.0349, Validation Loss: 0.0514, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 409, Train Loss: 0.0348, Validation Loss: 0.0513, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 410, Train Loss: 0.0347, Validation Loss: 0.0512, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 411, Train Loss: 0.0346, Validation Loss: 0.0511, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 412, Train Loss: 0.0345, Validation Loss: 0.0511, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 413, Train Loss: 0.0344, Validation Loss: 0.0510, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 414, Train Loss: 0.0343, Validation Loss: 0.0509, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 415, Train Loss: 0.0342, Validation Loss: 0.0508, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 416, Train Loss: 0.0341, Validation Loss: 0.0508, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 417, Train Loss: 0.0340, Validation Loss: 0.0507, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 418, Train Loss: 0.0339, Validation Loss: 0.0506, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9961, LR: 0.0001
# Epoch 419, Train Loss: 0.0338, Validation Loss: 0.0506, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9962, LR: 0.0001
# Epoch 420, Train Loss: 0.0337, Validation Loss: 0.0505, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9962, LR: 0.0001
# Epoch 421, Train Loss: 0.0336, Validation Loss: 0.0504, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9962, LR: 0.0001
# Epoch 422, Train Loss: 0.0335, Validation Loss: 0.0503, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9962, LR: 0.0001
# Epoch 423, Train Loss: 0.0335, Validation Loss: 0.0503, Val Accuracy: 0.9870, Precision: 0.9405, Recall: 0.9634, F1: 0.9518, AUC: 0.9962, LR: 0.0001
# Epoch 424, Train Loss: 0.0334, Validation Loss: 0.0502, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9962, LR: 0.0001
# Epoch 425, Train Loss: 0.0333, Validation Loss: 0.0501, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9962, LR: 0.0001
# Epoch 426, Train Loss: 0.0332, Validation Loss: 0.0501, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9962, LR: 0.0001
# Epoch 427, Train Loss: 0.0331, Validation Loss: 0.0500, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9962, LR: 0.0001
# Epoch 428, Train Loss: 0.0330, Validation Loss: 0.0499, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9962, LR: 0.0001
# Epoch 429, Train Loss: 0.0329, Validation Loss: 0.0499, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 430, Train Loss: 0.0328, Validation Loss: 0.0498, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 431, Train Loss: 0.0327, Validation Loss: 0.0497, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 432, Train Loss: 0.0327, Validation Loss: 0.0497, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 433, Train Loss: 0.0326, Validation Loss: 0.0496, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 434, Train Loss: 0.0325, Validation Loss: 0.0495, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 435, Train Loss: 0.0324, Validation Loss: 0.0495, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 436, Train Loss: 0.0323, Validation Loss: 0.0494, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 437, Train Loss: 0.0322, Validation Loss: 0.0493, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 438, Train Loss: 0.0321, Validation Loss: 0.0493, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 439, Train Loss: 0.0321, Validation Loss: 0.0492, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 440, Train Loss: 0.0320, Validation Loss: 0.0492, Val Accuracy: 0.9862, Precision: 0.9401, Recall: 0.9573, F1: 0.9486, AUC: 0.9963, LR: 0.0001
# Epoch 441, Train Loss: 0.0319, Validation Loss: 0.0491, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9963, LR: 0.0001
# Epoch 442, Train Loss: 0.0318, Validation Loss: 0.0490, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9963, LR: 0.0001
# Epoch 443, Train Loss: 0.0317, Validation Loss: 0.0490, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 444, Train Loss: 0.0316, Validation Loss: 0.0489, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 445, Train Loss: 0.0316, Validation Loss: 0.0488, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 446, Train Loss: 0.0315, Validation Loss: 0.0488, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 447, Train Loss: 0.0314, Validation Loss: 0.0487, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 448, Train Loss: 0.0313, Validation Loss: 0.0487, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 449, Train Loss: 0.0312, Validation Loss: 0.0486, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 450, Train Loss: 0.0312, Validation Loss: 0.0485, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 451, Train Loss: 0.0311, Validation Loss: 0.0485, Val Accuracy: 0.9870, Precision: 0.9458, Recall: 0.9573, F1: 0.9515, AUC: 0.9964, LR: 0.0001
# Epoch 452, Train Loss: 0.0310, Validation Loss: 0.0484, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 453, Train Loss: 0.0309, Validation Loss: 0.0484, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 454, Train Loss: 0.0308, Validation Loss: 0.0483, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 455, Train Loss: 0.0308, Validation Loss: 0.0482, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 456, Train Loss: 0.0307, Validation Loss: 0.0482, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 457, Train Loss: 0.0306, Validation Loss: 0.0481, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 458, Train Loss: 0.0305, Validation Loss: 0.0481, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 459, Train Loss: 0.0304, Validation Loss: 0.0480, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 460, Train Loss: 0.0304, Validation Loss: 0.0479, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 461, Train Loss: 0.0303, Validation Loss: 0.0479, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9964, LR: 0.0001
# Epoch 462, Train Loss: 0.0302, Validation Loss: 0.0478, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 463, Train Loss: 0.0301, Validation Loss: 0.0478, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 464, Train Loss: 0.0301, Validation Loss: 0.0477, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 465, Train Loss: 0.0300, Validation Loss: 0.0477, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 466, Train Loss: 0.0299, Validation Loss: 0.0476, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 467, Train Loss: 0.0298, Validation Loss: 0.0476, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 468, Train Loss: 0.0298, Validation Loss: 0.0475, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 469, Train Loss: 0.0297, Validation Loss: 0.0474, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 470, Train Loss: 0.0296, Validation Loss: 0.0474, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 471, Train Loss: 0.0295, Validation Loss: 0.0473, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 472, Train Loss: 0.0295, Validation Loss: 0.0473, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 473, Train Loss: 0.0294, Validation Loss: 0.0472, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 474, Train Loss: 0.0293, Validation Loss: 0.0472, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 475, Train Loss: 0.0292, Validation Loss: 0.0471, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 476, Train Loss: 0.0292, Validation Loss: 0.0471, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 477, Train Loss: 0.0291, Validation Loss: 0.0470, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 478, Train Loss: 0.0290, Validation Loss: 0.0470, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 479, Train Loss: 0.0290, Validation Loss: 0.0469, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 480, Train Loss: 0.0289, Validation Loss: 0.0469, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 481, Train Loss: 0.0288, Validation Loss: 0.0468, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 482, Train Loss: 0.0287, Validation Loss: 0.0468, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 483, Train Loss: 0.0287, Validation Loss: 0.0467, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 484, Train Loss: 0.0286, Validation Loss: 0.0467, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 485, Train Loss: 0.0285, Validation Loss: 0.0466, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 486, Train Loss: 0.0285, Validation Loss: 0.0466, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 487, Train Loss: 0.0284, Validation Loss: 0.0465, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9965, LR: 0.0001
# Epoch 488, Train Loss: 0.0283, Validation Loss: 0.0465, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 489, Train Loss: 0.0283, Validation Loss: 0.0464, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 490, Train Loss: 0.0282, Validation Loss: 0.0464, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 491, Train Loss: 0.0281, Validation Loss: 0.0463, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 492, Train Loss: 0.0280, Validation Loss: 0.0463, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 493, Train Loss: 0.0280, Validation Loss: 0.0462, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 494, Train Loss: 0.0279, Validation Loss: 0.0462, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 495, Train Loss: 0.0278, Validation Loss: 0.0461, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 496, Train Loss: 0.0278, Validation Loss: 0.0461, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 497, Train Loss: 0.0277, Validation Loss: 0.0460, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 498, Train Loss: 0.0276, Validation Loss: 0.0460, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 499, Train Loss: 0.0276, Validation Loss: 0.0459, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001
# Epoch 500, Train Loss: 0.0275, Validation Loss: 0.0459, Val Accuracy: 0.9878, Precision: 0.9515, Recall: 0.9573, F1: 0.9544, AUC: 0.9966, LR: 0.0001

# %%
protein_mapping, substrate_mapping = get_mapping(p_df, s_df)

# Apply the debugging function to map edges
mapped_ppi_edges_df = map_edges_debug(ppi_df, protein_mapping, protein_mapping, 'PPI')
mapped_ssi_edges_df = map_edges_debug(ssi_df, substrate_mapping, substrate_mapping, 'SSI')
mapped_tp_s_df = map_edges_debug(test_tp_s_df, protein_mapping, substrate_mapping, 'TP-S')

# Convert features to numpy arrays
s_features = s_df.values
p_features = p_df.values

# Check shapes to ensure correct dimensions
print(f"s_features shape: {s_features.shape}")  # Expected (183, 1536)
print(f"p_features shape: {p_features.shape}")  # Expected (237197, 2048)

# Normalize node features (normalizes columns to have mean 0 and variance 1)
s_features = (s_features - np.mean(s_features, axis=0)) / np.std(s_features, axis=0)
p_features = (p_features - np.mean(p_features, axis=0)) / np.std(p_features, axis=0)

device = torch.device('cpu')  # Temporarily switch to CPU


transform_s = Linear(1536, 2048).to(device) # Change depending on the number of features
transform_p = Linear(2048, 2048).to(device)

s_features_transformed = transform_in_batches(s_features, transform_s)
p_features_transformed = transform_in_batches(p_features, transform_p)

# Convert back to tensors
s_features_tensor = torch.tensor(s_features_transformed, dtype=torch.float).to(device)
p_features_tensor = torch.tensor(p_features_transformed, dtype=torch.float).to(device)

# Combine features, vertically stacks features (dim=0) to create a single tensor
all_features = torch.cat([p_features_tensor, s_features_tensor], dim=0)

protein_ids = set(p_df.index)
substrate_ids = set(s_df.index)

# Create edge index tensors for test
test_edges_tp_s = torch.tensor(test_tp_s_df[['source', 'target']].values.T, dtype=torch.long)
test_labels_tp_s = torch.tensor(test_tp_s_df['label'].values, dtype=torch.float)


# Load the best model
model.load_state_dict(torch.load('/data/servilla/DT_HGNN/data/Models_saves/best_model.pth'))

# Test the model

test_loss, test_accuracy, test_precision, test_recall, test_f1, test_auc = test(data.x_dict, data.edge_index_dict, test_edges_tp_s, test_labels_tp_s)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Test Precision: {test_precision:.4f}, "
      f"Test Recall: {test_recall:.4f}, Test F1: {test_f1:.4f}, Test AUC: {test_auc:.4f}")

# Plot training and validation losses
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.savefig('/data/servilla/DT_HGNN/Plots/loss_plot.png')
plt.show()

from sklearn.metrics import confusion_matrix, roc_curve

# Plot Confusion Matrix
def plot_confusion_matrix(labels, preds):
    preds_binary = (preds > 0.5).astype(int)
    cm = confusion_matrix(labels, preds_binary)
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, cmap='Blues')
    plt.title('Confusion Matrix')
    plt.colorbar()
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig('/data/servilla/DT_HGNN/Plots/confusion_matrix.png')
    plt.show()

# Plot ROC Curve
def plot_roc_curve(labels, preds):
    fpr, tpr, _ = roc_curve(labels, preds)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, marker='.')
    plt.title('ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.grid(True)
    plt.savefig('/data/servilla/DT_HGNN/Plots/roc_curve.png')
    plt.show()

# After testing, plot confusion matrix and ROC curve
plot_confusion_matrix(test_labels_tp_s.cpu().numpy(), torch.sigmoid(out).cpu().numpy())
plot_roc_curve(test_labels_tp_s.cpu().numpy(), torch.sigmoid(out).cpu().numpy())
# Out:
# s_features shape: (183, 1536)
# p_features shape: (237197, 2048)
# Number of samples: 183
# Number of samples: 237197
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 40
#      37 substrate_ids = set(s_df.index)
#      39 # Create edge index tensors for test
# ---> 40 test_edges_tp_s = torch.tensor(test_tp_s_df[['source', 'target']].values.T, dtype=torch.long)
#      41 test_labels_tp_s = torch.tensor(test_tp_s_df['label'].values, dtype=torch.float)
#      44 # Load the best model
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint64, uint32, uint16, uint8, and bool.
