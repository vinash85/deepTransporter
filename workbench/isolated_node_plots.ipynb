# %%
import matplotlib.pyplot as plt

# Data for training with only positive edges
positive_edges_data = {
    "tp_s_edges_returned": [0, 1, 5, 10],
    "Test Loss": [0.1922, 0.1309, 0.1069, 0.1141],
    "Test Accuracy": [0.9800, 1.0000, 1.0000, 1.0000],
    "Precision": [1.0000, 1.0000, 1.0000, 1.0000],
    "Recall": [0.9800, 1.0000, 1.0000, 1.0000],
    "F1": [0.9899, 1.0000, 1.0000, 1.0000],
    "Validation Loss": [0.1067, 0.0904, 0.1078, 0.0868],
    "Val Accuracy": [0.9651, 0.9788, 0.9654, 0.9771],
}

# Data for training with both positive and negative edges
pos_neg_edges_data = {
    "tp_s_edges_returned": [0, 1, 5, 10],
    "Test Loss": [0.4096, 0.3651, 0.2586, 0.2826],
    "Test Accuracy": [0.7200, 0.8400, 0.9000, 0.8400],
    "Precision": [1.0000, 1.0000, 1.0000, 1.0000],
    "Recall": [0.7200, 0.8400, 0.9000, 0.8400],
    "F1": [0.8372, 0.9130, 0.9474, 0.9130],
    "Validation Loss": [0.1408, 0.1321, 0.1249, 0.1318],
    "Val Accuracy": [0.9499, 0.9636, 0.9568, 0.9609],
}

# Plotting
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot Test Loss
axes[0, 0].plot(positive_edges_data["tp_s_edges_returned"], positive_edges_data["Test Loss"], label="Pos Edges Only", marker='o')
axes[0, 0].plot(pos_neg_edges_data["tp_s_edges_returned"], pos_neg_edges_data["Test Loss"], label="Pos & Neg Edges", marker='o')
axes[0, 0].set_title("Test Loss")
axes[0, 0].set_xlabel("tp_s edges returned")
axes[0, 0].set_ylabel("Loss")
axes[0, 0].legend()

# Plot Test Accuracy
axes[0, 1].plot(positive_edges_data["tp_s_edges_returned"], positive_edges_data["Test Accuracy"], label="Pos Edges Only", marker='o')
axes[0, 1].plot(pos_neg_edges_data["tp_s_edges_returned"], pos_neg_edges_data["Test Accuracy"], label="Pos & Neg Edges", marker='o')
axes[0, 1].set_title("Test Accuracy")
axes[0, 1].set_xlabel("tp_s edges returned")
axes[0, 1].set_ylabel("Accuracy")
axes[0, 1].legend()

# Plot Validation Loss
axes[1, 0].plot(positive_edges_data["tp_s_edges_returned"], positive_edges_data["Validation Loss"], label="Pos Edges Only", marker='o')
axes[1, 0].plot(pos_neg_edges_data["tp_s_edges_returned"], pos_neg_edges_data["Validation Loss"], label="Pos & Neg Edges", marker='o')
axes[1, 0].set_title("Validation Loss")
axes[1, 0].set_xlabel("tp_s edges returned")
axes[1, 0].set_ylabel("Loss")
axes[1, 0].legend()

# Plot Validation Accuracy
axes[1, 1].plot(positive_edges_data["tp_s_edges_returned"], positive_edges_data["Val Accuracy"], label="Pos Edges Only", marker='o')
axes[1, 1].plot(pos_neg_edges_data["tp_s_edges_returned"], pos_neg_edges_data["Val Accuracy"], label="Pos & Neg Edges", marker='o')
axes[1, 1].set_title("Validation Accuracy")
axes[1, 1].set_xlabel("tp_s edges returned")
axes[1, 1].set_ylabel("Accuracy")
axes[1, 1].legend()

plt.tight_layout()
plt.show()
